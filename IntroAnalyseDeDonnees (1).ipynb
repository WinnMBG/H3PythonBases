# %%
# !dir
# Out:
#  Le volume dans le lecteur C s'appelle Windows
#  Le num‚ro de s‚rie du volume est BE20-5F7E
#
#  R‚pertoire de C:\Users\winn7\OneDrive\Bureau\AnalyseDeDonnes
#
# 19/09/2022  09:35    <DIR>          .
# 19/09/2022  09:35    <DIR>          ..
# 19/09/2022  09:33    <DIR>          .ipynb_checkpoints
# 19/09/2022  09:35               589 Untitled.ipynb
#                1 fichier(s)              589 octets
#                3 R‚p(s)  51ÿ388ÿ440ÿ576 octets libres

# %%
import pandas as pd
import numpy as np
import seaborn as sb

# %% [markdown]
# # Introduction à l'analyse de données
# ## Exercice 1

# %%
hp=pd.read_csv('./house_pricing.csv')
hp.head(10)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
# 5   6          50       RL         85.0    14115   Pave   NaN      IR1
# 6   7          20       RL         75.0    10084   Pave   NaN      Reg
# 7   8          60       RL          NaN    10382   Pave   NaN      IR1
# 8   9          50       RM         51.0     6120   Pave   NaN      Reg
# 9  10         190       RL         50.0     7420   Pave   NaN      Reg
#
#   LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# ...

# %%
hp.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
#                   ...
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# Length: 81, dtype: object

# %%
sb.set_theme()
sb.relplot(
    data=hp,
    x="SalePrice", y="LotArea"
)

# %%
sb.set_theme()
sb.relplot(
    data=hp[ (hp['SalePrice'] < 500000) & (hp['LotArea'] < 20000)],
    x="LotArea", y="SalePrice"
)

# %%
sb.set_theme()
sb.relplot(
    data=hp,
    x='LotFrontage', y='LotArea')

# %%
sb.set_theme()
sb.relplot(
    data=hp[ (hp['LotFrontage'] < 200) & (hp['LotArea'] < 100000)],
    x='LotFrontage', y='LotArea')

# %% [markdown]
# ## Exercie 2: Visualisation des données

# %% [markdown]
# ## 2.1)

# %%
sp=pd.read_csv('./sales_predictions.csv')
sp.tail(10)
# Out:
#                date  date_block_num  shop_id  item_id  item_price  \
# 2935839  24.10.2015              33       25     7315       399.0
# 2935840  31.10.2015              33       25     7409       299.0
# 2935841  11.10.2015              33       25     7393       349.0
# 2935842  10.10.2015              33       25     7384       749.0
# 2935843  09.10.2015              33       25     7409       299.0
# 2935844  10.10.2015              33       25     7409       299.0
# 2935845  09.10.2015              33       25     7460       299.0
# 2935846  14.10.2015              33       25     7459       349.0
# 2935847  22.10.2015              33       25     7440       299.0
# 2935848  03.10.2015              33       25     7460       299.0
#
#          item_cnt_day
# 2935839           1.0
# 2935840           1.0
# 2935841           1.0
# 2935842           1.0
# 2935843           1.0
# 2935844           1.0
# 2935845           1.0
# 2935846           1.0
# 2935847           1.0
# ...

# %%
sb.set_theme()
sb.lineplot(
    data=sp,
    x='date', y='item_price')
# Out:
# <AxesSubplot: xlabel='date', ylabel='item_price'>

# %%
sp.shape
# Out:
# (2935849, 6)

# %%
#Utilisation de la fonction sample
sb.set_theme()
sb.lineplot(
    data=sp.sample(n=50),
    x='date', y='item_price')
# Out:
# <AxesSubplot: xlabel='date', ylabel='item_price'>

# %%
#to_datetime
sp.date=pd.to_datetime(sp.date)
sp.head(10)
sp.dtypes
# Out:
# date              datetime64[ns]
# date_block_num             int64
# shop_id                    int64
# item_id                    int64
# item_price               float64
# item_cnt_day             float64
# dtype: object

# %%
#Utilisation de la fonction sample
sb.set_theme()
sb.relplot(
    data=sp.sample(n=50),
    x='date', y='item_price', kind='line', aspect=1.5)

# %% [markdown]
# # Exercice 3: Visualisation des variables catégoriques

# %% [markdown]
# ## 3.**1**)

# %%
ibm=pd.read_csv('./ibm_hr_attrition.csv')
ibm.head(10)
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
# 5   32        No  Travel_Frequently       1005  Research & Development
# 6   59        No      Travel_Rarely       1324  Research & Development
# 7   30        No      Travel_Rarely       1358  Research & Development
# 8   38        No  Travel_Frequently        216  Research & Development
# 9   36        No      Travel_Rarely       1299  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# ...

# %%
ibm.shape
# Out:
# (1470, 35)

# %%
ibm.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
sb.set_theme()
sb.catplot(
    data=ibm[ ibm['Attrition']=='Yes'],
    x='JobSatisfaction', y='EmployeeNumber')

# %%
sb.set_theme()
sb.boxplot(
    data=ibm[ ibm['Attrition']=='Yes'],
    x='JobSatisfaction', y='EmployeeNumber')
# Out:
# <AxesSubplot: xlabel='JobSatisfaction', ylabel='EmployeeNumber'>

# %%
#question4 : On peut en conclure que il n'y a pas de valeur abérrantes pour ce boxplot
#question5 : Il n'y en a pas 
ibm.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
sb.set_theme()
sb.catplot(
    data=ibm[ ibm['Attrition']=='Yes'],
    x='TotalWorkingYears', y='EmployeeNumber', size=3, aspect=2)

# %%
sb.set_theme()
sb.catplot(
    data=ibm[ ibm['Attrition']=='Yes'],
    x='TotalWorkingYears', y='EmployeeNumber', kind='box', aspect=2)

# %%
#Sur ce boxplot, on a bien des valeurs aberrantes qui se dessinent.
#on va donc les isoler
tmp=ibm[ ((ibm['TotalWorkingYears']==2) | (ibm['TotalWorkingYears']==8) | (ibm['TotalWorkingYears']==12))]
tmp2=tmp[ tmp[(tmp['EmployeeNumber'] < 850) | (tmp['EmployeeNumber']) >1500]]
tmp2
# Out:
#       Age Attrition BusinessTravel  DailyRate Department  DistanceFromHome  \
# 0     NaN       NaN            NaN        NaN        NaN               NaN
# 3     NaN       NaN            NaN        NaN        NaN               NaN
# 5     NaN       NaN            NaN        NaN        NaN               NaN
# 6     NaN       NaN            NaN        NaN        NaN               NaN
# 24    NaN       NaN            NaN        NaN        NaN               NaN
# ...   ...       ...            ...        ...        ...               ...
# 1446  NaN       NaN            NaN        NaN        NaN               NaN
# 1452  NaN       NaN            NaN        NaN        NaN               NaN
# 1453  NaN       NaN            NaN        NaN        NaN               NaN
# 1454  NaN       NaN            NaN        NaN        NaN               NaN
# 1455  NaN       NaN            NaN        NaN        NaN               NaN
#
# ...

# %%
ibm.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
ibm['Attrition'].replace('Yes', 1)
ibm['Attrition'].replace('No',0)
ibm.tail(10)
# Out:
#       Age  Attrition     BusinessTravel  DailyRate              Department  \
# 1460   29          1      Travel_Rarely        468  Research & Development
# 1461   50          1      Travel_Rarely        410                   Sales
# 1462   39          1      Travel_Rarely        722                   Sales
# 1463   31          1         Non-Travel        325  Research & Development
# 1464   26          1      Travel_Rarely       1167                   Sales
# 1465   36          1  Travel_Frequently        884  Research & Development
# 1466   39          1      Travel_Rarely        613  Research & Development
# 1467   27          1      Travel_Rarely        155  Research & Development
# 1468   49          1  Travel_Frequently       1023                   Sales
# 1469   34          1      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 1460                28          4        Medical              1
# ...
